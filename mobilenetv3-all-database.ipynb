# %% [markdown]
# ## ① Setting
# - Import libraries
# - Load Data
#
# ----
# - Reference
#     - https://www.tensorflow.org/api_docs/python/tf/keras/applications/MobileNetV3Small

# %%
import tensorflow as tf
import numpy as np

from keras.applications import MobileNetV3Small

from keras.preprocessing import image
from keras import layers

from keras.layers import Dense, GlobalAveragePooling2D, Conv2D, MaxPooling2D, Flatten
from keras.models import Model, Sequential

import pathlib

# 로컬 데이터 경로 설정
data_dir = pathlib.Path("./dataset/")

height,width=180,180
training_batch_size=32

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    label_mode='categorical',
    labels="inferred",
    seed=123,
    image_size=(height,width),
    batch_size=training_batch_size
)

validation_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    label_mode='categorical',
    labels="inferred",
    seed=123,
    image_size=(height,width),
    batch_size=training_batch_size
)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 14001 files belonging to 14 classes.
# Using 11201 files for training.
# Found 14001 files belonging to 14 classes.
# Using 2800 files for validation.
# ['Corn___Common_rust', 'Corn___Gray_leaf_spot', 'Corn___Northern_Leaf_Blight', 'Corn___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___healthy']

# %% [markdown]
# ### ② Building a deep learning model

# %%
dnn_model = MobileNetV3Small(
    input_shape=None,
    alpha=1.0,
    minimalistic=False,
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    classes=14,
    pooling=None,
    dropout_rate=0.2,
    classifier_activation='softmax',
    include_preprocessing=True
)

for layer in dnn_model.layers:
    layer.trainable=False

dnn_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  rescaling_2 (Rescaling)     (None, None, None, 3)        0         ['input_3[0][0]']
#
#  Conv (Conv2D)               (None, None, None, 16)       432       ['rescaling_2[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, None, None, 16)       64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add_54 (TFOpLambda  (None, None, None, 16)       0         ['Conv/BatchNorm[0][0]']
#  )
#
#  re_lu_64 (ReLU)             (None, None, None, 16)       0         ['tf.math.add_54[0][0]']
#
#  tf.math.multiply_54 (TFOpL  (None, None, None, 16)       0         ['re_lu_64[0][0]']
#  ambda)
#
#  multiply_36 (Multiply)      (None, None, None, 16)       0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_54[0][0]']
#
#  expanded_conv/depthwise/pa  (None, None, None, 16)       0         ['multiply_36[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, None, None, 16)       144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, None, None, 16)       64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_65 (ReLU)             (None, None, None, 16)       0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_65[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.math.add_55 (TFOpLambda  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  )                                                                  /Conv_1[0][0]']
#
#  re_lu_66 (ReLU)             (None, 1, 1, 16)             0         ['tf.math.add_55[0][0]']
#
#  tf.math.multiply_55 (TFOpL  (None, 1, 1, 16)             0         ['re_lu_66[0][0]']
#  ambda)
#
#  expanded_conv/squeeze_exci  (None, None, None, 16)       0         ['re_lu_65[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_55[0][0]']
#
#  expanded_conv/project (Con  (None, None, None, 16)       256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, None, None, 16)       64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, None, None, 72)       1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, None, None, 72)       288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_67 (ReLU)             (None, None, None, 72)       0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, None, None, 72)       0         ['re_lu_67[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, None, None, 72)       648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, None, None, 72)       288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_68 (ReLU)             (None, None, None, 72)       0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, None, None, 24)       1728      ['re_lu_68[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, None, None, 24)       96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, None, None, 88)       2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, None, None, 88)       352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_69 (ReLU)             (None, None, None, 88)       0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, None, None, 88)       792       ['re_lu_69[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, None, None, 88)       352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_70 (ReLU)             (None, None, None, 88)       0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, None, None, 24)       2112      ['re_lu_70[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, None, None, 24)       96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, None, None, 24)       0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, None, None, 96)       2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, None, None, 96)       384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_56 (TFOpLambda  (None, None, None, 96)       0         ['expanded_conv_3/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_71 (ReLU)             (None, None, None, 96)       0         ['tf.math.add_56[0][0]']
#
#  tf.math.multiply_56 (TFOpL  (None, None, None, 96)       0         ['re_lu_71[0][0]']
#  ambda)
#
#  multiply_37 (Multiply)      (None, None, None, 96)       0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_56[0][0]']
#
#  expanded_conv_3/depthwise/  (None, None, None, 96)       0         ['multiply_37[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, None, None, 96)       2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, None, None, 96)       384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_57 (TFOpLambda  (None, None, None, 96)       0         ['expanded_conv_3/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_72 (ReLU)             (None, None, None, 96)       0         ['tf.math.add_57[0][0]']
#
#  tf.math.multiply_57 (TFOpL  (None, None, None, 96)       0         ['re_lu_72[0][0]']
#  ambda)
#
#  multiply_38 (Multiply)      (None, None, None, 96)       0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_57[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_38[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_58 (TFOpLambda  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_73 (ReLU)             (None, 1, 1, 96)             0         ['tf.math.add_58[0][0]']
#
#  tf.math.multiply_58 (TFOpL  (None, 1, 1, 96)             0         ['re_lu_73[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, None, None, 96)       0         ['multiply_38[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_58[0][0]']
#
#  expanded_conv_3/project (C  (None, None, None, 40)       3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, None, None, 40)       160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, None, None, 240)      9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, None, None, 240)      960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_59 (TFOpLambda  (None, None, None, 240)      0         ['expanded_conv_4/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_74 (ReLU)             (None, None, None, 240)      0         ['tf.math.add_59[0][0]']
#
#  tf.math.multiply_59 (TFOpL  (None, None, None, 240)      0         ['re_lu_74[0][0]']
#  ambda)
#
#  multiply_39 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_59[0][0]']
#
#  expanded_conv_4/depthwise   (None, None, None, 240)      6000      ['multiply_39[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, None, None, 240)      960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_60 (TFOpLambda  (None, None, None, 240)      0         ['expanded_conv_4/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_75 (ReLU)             (None, None, None, 240)      0         ['tf.math.add_60[0][0]']
#
#  tf.math.multiply_60 (TFOpL  (None, None, None, 240)      0         ['re_lu_75[0][0]']
#  ambda)
#
#  multiply_40 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_60[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_40[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_61 (TFOpLambda  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_76 (ReLU)             (None, 1, 1, 240)            0         ['tf.math.add_61[0][0]']
#
#  tf.math.multiply_61 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_76[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, None, None, 240)      0         ['multiply_40[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_61[0][0]']
#
#  expanded_conv_4/project (C  (None, None, None, 40)       9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, None, None, 40)       160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, None, None, 40)       0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, None, None, 240)      9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, None, None, 240)      960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_62 (TFOpLambda  (None, None, None, 240)      0         ['expanded_conv_5/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_77 (ReLU)             (None, None, None, 240)      0         ['tf.math.add_62[0][0]']
#
#  tf.math.multiply_62 (TFOpL  (None, None, None, 240)      0         ['re_lu_77[0][0]']
#  ambda)
#
#  multiply_41 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_62[0][0]']
#
#  expanded_conv_5/depthwise   (None, None, None, 240)      6000      ['multiply_41[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, None, None, 240)      960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_63 (TFOpLambda  (None, None, None, 240)      0         ['expanded_conv_5/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_78 (ReLU)             (None, None, None, 240)      0         ['tf.math.add_63[0][0]']
#
#  tf.math.multiply_63 (TFOpL  (None, None, None, 240)      0         ['re_lu_78[0][0]']
#  ambda)
#
#  multiply_42 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_63[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_42[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_64 (TFOpLambda  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_79 (ReLU)             (None, 1, 1, 240)            0         ['tf.math.add_64[0][0]']
#
#  tf.math.multiply_64 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_79[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, None, None, 240)      0         ['multiply_42[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_64[0][0]']
#
#  expanded_conv_5/project (C  (None, None, None, 40)       9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, None, None, 40)       160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, None, None, 40)       0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, None, None, 120)      4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, None, None, 120)      480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_65 (TFOpLambda  (None, None, None, 120)      0         ['expanded_conv_6/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_80 (ReLU)             (None, None, None, 120)      0         ['tf.math.add_65[0][0]']
#
#  tf.math.multiply_65 (TFOpL  (None, None, None, 120)      0         ['re_lu_80[0][0]']
#  ambda)
#
#  multiply_43 (Multiply)      (None, None, None, 120)      0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_65[0][0]']
#
#  expanded_conv_6/depthwise   (None, None, None, 120)      3000      ['multiply_43[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, None, None, 120)      480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_66 (TFOpLambda  (None, None, None, 120)      0         ['expanded_conv_6/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_81 (ReLU)             (None, None, None, 120)      0         ['tf.math.add_66[0][0]']
#
#  tf.math.multiply_66 (TFOpL  (None, None, None, 120)      0         ['re_lu_81[0][0]']
#  ambda)
#
#  multiply_44 (Multiply)      (None, None, None, 120)      0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_66[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_44[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_67 (TFOpLambda  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_82 (ReLU)             (None, 1, 1, 120)            0         ['tf.math.add_67[0][0]']
#
#  tf.math.multiply_67 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_82[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, None, None, 120)      0         ['multiply_44[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_67[0][0]']
#
#  expanded_conv_6/project (C  (None, None, None, 48)       5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, None, None, 48)       192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, None, None, 144)      6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, None, None, 144)      576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_68 (TFOpLambda  (None, None, None, 144)      0         ['expanded_conv_7/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_83 (ReLU)             (None, None, None, 144)      0         ['tf.math.add_68[0][0]']
#
#  tf.math.multiply_68 (TFOpL  (None, None, None, 144)      0         ['re_lu_83[0][0]']
#  ambda)
#
#  multiply_45 (Multiply)      (None, None, None, 144)      0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_68[0][0]']
#
#  expanded_conv_7/depthwise   (None, None, None, 144)      3600      ['multiply_45[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, None, None, 144)      576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_69 (TFOpLambda  (None, None, None, 144)      0         ['expanded_conv_7/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_84 (ReLU)             (None, None, None, 144)      0         ['tf.math.add_69[0][0]']
#
#  tf.math.multiply_69 (TFOpL  (None, None, None, 144)      0         ['re_lu_84[0][0]']
#  ambda)
#
#  multiply_46 (Multiply)      (None, None, None, 144)      0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_69[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_46[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_70 (TFOpLambda  (None, 1, 1, 144)            0         ['expanded_conv_7/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_85 (ReLU)             (None, 1, 1, 144)            0         ['tf.math.add_70[0][0]']
#
#  tf.math.multiply_70 (TFOpL  (None, 1, 1, 144)            0         ['re_lu_85[0][0]']
#  ambda)
#
#  expanded_conv_7/squeeze_ex  (None, None, None, 144)      0         ['multiply_46[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_70[0][0]']
#
#  expanded_conv_7/project (C  (None, None, None, 48)       6912      ['expanded_conv_7/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_7/project/Ba  (None, None, None, 48)       192       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
# ...
#  )
#
#  tf.math.add_74 (TFOpLambda  (None, None, None, 576)      0         ['expanded_conv_9/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_89 (ReLU)             (None, None, None, 576)      0         ['tf.math.add_74[0][0]']
#
#  tf.math.multiply_74 (TFOpL  (None, None, None, 576)      0         ['re_lu_89[0][0]']
#  ambda)
#
#  multiply_49 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_74[0][0]']
#
#  expanded_conv_9/depthwise   (None, None, None, 576)      14400     ['multiply_49[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, None, None, 576)      2304      ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_75 (TFOpLambda  (None, None, None, 576)      0         ['expanded_conv_9/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_90 (ReLU)             (None, None, None, 576)      0         ['tf.math.add_75[0][0]']
#
#  tf.math.multiply_75 (TFOpL  (None, None, None, 576)      0         ['re_lu_90[0][0]']
#  ambda)
#
#  multiply_50 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_75[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            0         ['multiply_50[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            83088     ['expanded_conv_9/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            0         ['expanded_conv_9/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            83520     ['expanded_conv_9/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_76 (TFOpLambda  (None, 1, 1, 576)            0         ['expanded_conv_9/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_91 (ReLU)             (None, 1, 1, 576)            0         ['tf.math.add_76[0][0]']
#
#  tf.math.multiply_76 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_91[0][0]']
#  ambda)
#
#  expanded_conv_9/squeeze_ex  (None, None, None, 576)      0         ['multiply_50[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_76[0][0]']
#
#  expanded_conv_9/project (C  (None, None, None, 96)       55296     ['expanded_conv_9/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_9/project/Ba  (None, None, None, 96)       384       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, None, None, 96)       0         ['expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, None, None, 576)      55296     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, None, None, 576)      2304      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_77 (TFOpLambda  (None, None, None, 576)      0         ['expanded_conv_10/expand/Batc
#  )                                                                  hNorm[0][0]']
#
#  re_lu_92 (ReLU)             (None, None, None, 576)      0         ['tf.math.add_77[0][0]']
#
#  tf.math.multiply_77 (TFOpL  (None, None, None, 576)      0         ['re_lu_92[0][0]']
#  ambda)
#
#  multiply_51 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_10/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_77[0][0]']
#
#  expanded_conv_10/depthwise  (None, None, None, 576)      14400     ['multiply_51[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, None, None, 576)      2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_78 (TFOpLambda  (None, None, None, 576)      0         ['expanded_conv_10/depthwise/B
#  )                                                                  atchNorm[0][0]']
#
#  re_lu_93 (ReLU)             (None, None, None, 576)      0         ['tf.math.add_78[0][0]']
#
#  tf.math.multiply_78 (TFOpL  (None, None, None, 576)      0         ['re_lu_93[0][0]']
#  ambda)
#
#  multiply_52 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_78[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_52[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_79 (TFOpLambda  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  )                                                                  ite/Conv_1[0][0]']
#
#  re_lu_94 (ReLU)             (None, 1, 1, 576)            0         ['tf.math.add_79[0][0]']
#
#  tf.math.multiply_79 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_94[0][0]']
#  ambda)
#
#  expanded_conv_10/squeeze_e  (None, None, None, 576)      0         ['multiply_52[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_79[0][0]']
#
#  expanded_conv_10/project (  (None, None, None, 96)       55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, None, None, 96)       384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, None, None, 96)       0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, None, None, 576)      55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, None, None, 576)      2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_80 (TFOpLambda  (None, None, None, 576)      0         ['Conv_1/BatchNorm[0][0]']
#  )
#
#  re_lu_95 (ReLU)             (None, None, None, 576)      0         ['tf.math.add_80[0][0]']
#
#  tf.math.multiply_80 (TFOpL  (None, None, None, 576)      0         ['re_lu_95[0][0]']
#  ambda)
#
#  multiply_53 (Multiply)      (None, None, None, 576)      0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_80[0][0]']
#
# ==================================================================================================
# Total params: 939120 (3.58 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### ③ Train Model

# %%
dnn_model.compile(
    optimizer="adam",
    loss='categorical_crossentropy',
    metrics=['categorical_accuracy'])

# %%
epochs=10
history = dnn_model.fit(
    train_ds, 
    validation_data=validation_ds, 
    epochs=epochs
)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/donghyun/Desktop/Dev/project/HYU/BloomMate/BloomMate-ML/mobilenetv3-all-database.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/Users/donghyun/Desktop/Dev/project/HYU/BloomMate/BloomMate-ML/mobilenetv3-all-database.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> epochs=10
# ----> <a href='vscode-notebook-cell:/Users/donghyun/Desktop/Dev/project/HYU/BloomMate/BloomMate-ML/mobilenetv3-all-database.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> history = dnn_model.fit(
#       <a href='vscode-notebook-cell:/Users/donghyun/Desktop/Dev/project/HYU/BloomMate/BloomMate-ML/mobilenetv3-all-database.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     train_ds,
#       <a href='vscode-notebook-cell:/Users/donghyun/Desktop/Dev/project/HYU/BloomMate/BloomMate-ML/mobilenetv3-all-database.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a>     validation_data=validation_ds,
#       <a href='vscode-notebook-cell:/Users/donghyun/Desktop/Dev/project/HYU/BloomMate/BloomMate-ML/mobilenetv3-all-database.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a>     epochs=epochs
#       <a href='vscode-notebook-cell:/Users/donghyun/Desktop/Dev/project/HYU/BloomMate/BloomMate-ML/mobilenetv3-all-database.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> )
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /var/folders/05/f27xdntx0w1d15nqqws7822w0000gn/T/__autograph_generated_file6qsx9986.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py", line 1377, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py", line 1360, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py", line 1349, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py", line 1127, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py", line 1185, in compute_loss
#         return self.compiled_loss(
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/engine/compile_utils.py", line 277, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/losses.py", line 143, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/losses.py", line 270, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/losses.py", line 2221, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/Users/donghyun/Library/Python/3.9/lib/python/site-packages/keras/src/backend.py", line 5575, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 14) and (None, 5, 5, 576) are incompatible
